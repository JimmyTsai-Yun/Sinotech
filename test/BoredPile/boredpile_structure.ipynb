# %%
import cv2
import numpy as np
import sys
import os 
from pdf2image import convert_from_path
import easyocr
import csv
import matplotlib.pyplot as plt

# %%
def set_working_directory():
    # 當程式被 PyInstaller 打包時
    if hasattr(sys, '_MEIPASS'):
        # 設置工作目錄為可執行文件所在的目錄
        exe_dir = os.path.dirname(os.path.abspath(sys.executable))
    else:
        # 當程式在開發環境中執行時
        exe_dir = os.path.dirname(os.path.abspath(__file__))
        # 回到上一層目錄，即專案根目錄
        exe_dir = os.path.dirname(exe_dir)

    # 設置工作目錄為可執行文件所在的目錄
    os.chdir(exe_dir)

    return os.getcwd()

# %%
image = convert_from_path('./myown.pdf', dpi =300, poppler_path="..\\..\\poppler-24.02.0\\Library\\bin")

# %%
img = np.asarray(image[0])

# img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
img_gray = cv2.cvtColor(img, cv2.COLOR_RGB2GRAY)

# %%
reader = easyocr.Reader(['ch_tra','en'])

bounds = reader.readtext(img_gray, detail=1)
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
for index in bounds:
  print(index[1])
# Out:
# 結櫧
# 說 明
# STRUCTURAL GENERAL NOTES
# 除非另有說明
# UNLESS OTHERWISE NOTED
# 所有結構混凝土應為常重混凝土且其28天之最小抗壓強度應如下列:
# 施工說明
# GENERAL
# ALL STRUCTURAL CONCRETE SHALL BE OF NORMAL WEIGHT CONCRETE WITH MINIMUM COMPRESSIVE STRENGTH
# CONSTRUCTION NOTES
# AT 28 DAYS (fc) AS FOLL0W$:
# 廠商於施工前必須先行確認設計圖上之所有尺寸及可能影響施工之任何狀況並告知工程司設計圖上有疑義處
# 鋼筋保護層厚度應至少如下:
# THE CONTRACTOR SHALL IMMEDIATELY UPON RECEIPT THEREOF,
# CHECK CONTRACT DRAWINGS
# FURNISHED FOR
# 連續壁
# f'c2 245 kgf/cm2
# CONCRETE PROTECTION FOR REINFORCEMENT SHALL BE NOT LESS THAN THAT FOLLOWS:
# THE DIMENSIONS AND CONDITIONS AFFECTING HIS WORKS AND SHALL PROMPTLY NOTIFY THE ENGINEER OF
# DIAPHRAGM WALLS
# f'c2 350 kgf/cm2
# OMISSIONS OR DISCREPANCIES
# (複合牆適
# 外露面直接接觸水
# 土壤`混凝土舖面或防水膜者
# 75 mm
# (FOR COMPOSITE WALL)
# CONCRETE CAST AGAINST AND PERMANENTLY EXPOSED TO WATER SOIL BLINDING
# 2.
# 為使高程值為正值
# 本設計圖所有高程標示均以中華民國台灣省基隆潮汐測站之平均海平面下100公尺處為基準點
# CONCRETE OR WATERPROOFING MEMBRANE
# ALL ELEVATIONS SHOWN ON THESE CONTRACT DRAWINGS ARE RELATED TO THE DATUM 1O0 m BELOW THE
# MEAN SEA LEVEL AT TIDAL STATION KEELUNG
# TAIWAN, REPUBLIC OF CHINA TO AVOID NEGATIVE FIGURES FOR
# 無筋混凝土(保護
# 舖底)
# f'c2 l40 kgf/cm2
# 外露直暴露於室外
# ELEVATIONS
# PLAIN (PROTECTIVE BLINDING) CONCRETE
# CONCRETE EXPOSED TO WEATHER
# 結構體之高程控制
# 以低軌之鋼軌頂面為基準
# 水平控制則以軌道線形為基準
# 般結構(含軌床
# 次混凝土)
# f'c2 280 kgf/cm
# (i) 主筋
# 50 mm
# THE VERTICAL CONTROL OF THE STRUCTURE IS BASED ON THE ELEVATION OF THE TOp OF LOWER RAIL
# GENERAL STRUCTURAL WORKS (INCLUDE 2nd STAGE CONCRETE OF TRACK BED)
# PRIMARY REINFORCEMENT
# HORIZONTAL CONTROL IS BASED ON THE TRACK ALIGNMENT
# 預鑄混凝土隧道環片
# f'c2 450 kgf/cm2
# (ii)
# 箍筋~繫筋~螺旋箍筋
# 40 mm
# 本設計圖所有尺寸標示均以公厘為單位 所有高程標示均以公尺為單位
# PRECAST CONCRETE TUNNEL LINING
# STIRRUPS
# TIES AND SPIRALS
# ALL DIMENSIONS ARE IN MILLIMETERS AND ALL ELEVATIONS ARE IN METERS
# 隧道仰拱(二次混凝土)
# f'c2 210 kgf/cm2
# Giii)月台板及牆主筋
# 25 mm
# 本設計圖標示之樓板高程係指結構面樓板高程 (SFL).
# TUNNEL INVERT CONCRETE (2nd STAGE CONCRETE)
# PRIMARY REINFORCEMENT FOR PLATFORM SLAB AND ITS SUPPORTING WALL
# FLOOR LEVELS SHOWN
# THESE CONTRACT DRAWINGS ARE STRUCTURAL FLOOR SLAB LEVELS GSFL)
# 場鑄隧道襯砌
# f'c2 280 kgf/cm2
# 外露面暴露於鹽水中或有受鹽水噴灑之虞者
# l00 mm
# 本設計圖標示之高程及尺寸係指結構完工需求面
# CAST-IN- PLACE CONCRETE LINING
# COlICRETE EXPOSED TO SALT WATER OR SALT WATER SPRAY
# LEVELS AND DIMENSIONS SHOWN ARE REFERRED TO THE REQUIRED COMPLETED STRUCTURAL SURFACES
# 場鑄樁
# f'c2 280 kgf/cm2
# 混凝土蓋板
# 40 mm
# 廠商必須考慮可能影響結構尺寸之施工誤差及連續壁或其他開挖擋
# 設施撓度
# 以保持永久結構之設計尺寸需求
# CAST-IN-PLACE PILE
# CONCRETE COVER
# THE CONTRACTOR SHALL CONSIDER CONSTRUCTION TOLERANCE AND DEFLECTION OF DIAPHRAGM WALL OR THE
# OTHER EXCAVATION SUPPORTS WHICH MAY AFFECTING STRUCTURE SIZE TO KEEP THE DESIGN DIMENSIONS
# 鋼筋:
# 內面僅暴露於空氣中之
# REINFORCEMENT:
# CONCRETE EXPOSED TO AIR ONLY
# 設計準則及施工規範
# DESIGN CRITERIA AND SPECIFICATIONS
# (a)直徑大於或等於13mm之鋼筋應符合CNS 560 SD42OW之鋼材
# fy2 4200 kgf/cm2
# (i) 主筋
# 40 mm
# REINFORCEMENT OF 13 mm OR LARGER IN DIAMETER SHALL CONFORM To CNS 560,
# PRIMARY REINFORCEMENT
# 所有材料及
# 法均應符合本標施工技術規範及特定條款規定
# 50420|//.
# ALL MATERIALS AND WORKMANSHIP SHALL COMPLY WITH PROJECT SPECIFICATlONS
# (ii)箍筋`繫筋`螺旋箍筋
# 30 mm
# (b)
# 直徑小於或等於1Omm之鋼筋應符合CNS 560 SD28OW/鋼材;或符合(N$ 560,$D280
# fy2 2800 kgf/cm2
# STIRRUPS, TIES AND SPIRALS
# 2.本標結構設計係依據下列規範:
# 之鋼材之規定
# THE STRUCTURAL DESIGN IS BASED ON THE FOLLOWING DOCUMENTS:
# Giii)月台板及牆主筋
# 25 mm
# REINFORCEMENT OF 10 mm OR SMALLER
# DIAMETER SHALL CONFORM To CNS560,
# 5D280|/ 0R (|/$ 560 $0280
# PRIMARY REINFORCEMENT FOR PLATFORM SLAB AND ITS SUPPORTING WALL
# (a)
# 台北捷運係統-土木工程設計準則中文版第01版
# TRTS
# CIVIL ENGINEERING DESIGN CRITERION" lst ED. IN CHINESE
# (C)
# 除符合CNS 560 SD420W SD280W之鋼筋外 其餘所有鋼筋若需焊接均應提送符合AWS D1.4焊接程序規定的材料
# 預鑄混凝土隧道環片
# PRECAST CONCRETE TUNNEL LINING
# Gb)ACI(美國混凝土協會)- BUILDING CODE REQUIREMENTS
# STRUCTURAL CONCRETE (ACI
# 05)
# 性質報告
# SD420W/焊接鋼筋之焊材應為E9OxX SD280W焊接鋼筋之焊材應為E7OxX 並均應符合AWS
# D1.4規定
# "BUILDING CODE REQUlREMENTS FOR STRUCTURAL CONCRETE'
# (/C| 318-05)
# ALL REINFORCEMENT TO BE WELDED ARE REQUIRED TO HAVE
# REPORT OF MATERIAL PROPERTIES NECESSARY
# 牠側
# 40 mm
# TO CONFORM TO WELDING PROCEDURES SPECIFIED IN AWS D14 EXCEPT FOR CNS 560
# $D420W/ SD280W/), ALL
# OTHER FACE
# (c) INTERNATIONAL BUILDING CODE--2006版(IBC)
# WELDS OF REINFORCEMENT SHALL BE E9OXX FOR SD42oW & E7OXX FOR SD28oW AND CONFORM TO AWS
# "NTERNATIONAL BUILDING CODE'
# 2006 EDITION (IBC)
# D1.4
# 內側
# 30 mm
# INTERNAL FACE
# 次序
# 日期
# 內
# 谷
# DD(
# D0PTS
# (d)中華民國內政部頒布之"建築技術規則"
# 結構鋼(永久結構)應符合ASTM A36(或CN$ 2473/CNS 2947)規定
# fy2 2500 kgf/cm2
# Mo
# Date
# Descriotion
# MINISTRY OF INTERIOR
# R.O.C
# BUILDING CONSTRUCTION REGULATIONS"
# STRUCTURAL STEEL (FOR PERMANENT STRUCTURES) SHALL CONFORM TO ASTM A36(OR
# 連續壁(雙面
# 75 mm
# 准
# 改 Revisions
# Aoproved
# (N$ 2473/(|$ 2947)
# DIAPHRAGM WALLS (BOTH FACES)
# (e
# 國州際公路及運輸官員協會制訂之"STANDARD SPECIFICATION FOR HIGHWAY BRIDGES"並併入美國
# 參考圖號
# 電腦圖號
# 0882s1$010
# Ref.
# 0
# CLD
# M0
# 構設計課制訂之修定版
# 或(N$13812 $|4908
# (N$ 13812 $|490(
# CNS 13812 SN490CM之規定
# fy2 3o00 kgf/cm2
# 因應公共管線~建築
# 係統化設施~環控係統及機電設備等需求之預埋管件
# 如預埋管~預埋件
# 套筒`導管`基座
# 加州運輸部結
# OR CONFORM TO
# CN$ 13812 $14903, (|$ 13812 $|490( (|$ 13812 SN490C|
# 比例
# 單位
# "STANDARD SPECIFICATIONS FOR HIGHWAY BRIDGES'
# ADOPTED BY THE AMERICAN ASSOCIATlON OF STATE
# 及某些凹槽或開孔 也許並未完整地標示於結構圖上'廠商於施工前必須參考公共管線`建築
# 係統化設施~環控
# Scale
# Unit
# HIGHWAY AND TRANSPORTATION OFFICIALS INC.
# WITH REVISIONS BY STATE OF CALIFORNIA DEPARTMENT OF
# 或ASTM A572 50級規定
# fy2 3500 kgf/cm2
# 係統及機電設備等相
# ]說(由其他單位設計)先行和工程司確認其位置及詳圖
# TRANSPORTATlON OFFICE OF STRUCTURE DESIGN (C-AASHTO)
# OR CONFORM TO ASTM A572 GRADE 50
# EMBEDDED ITEMS SUCH AS PIPES,
# INSERTS, SLEEVES
# CONDUITS
# PLINTHS AND SOME RECESSES OR OPENINGS
# 中華民國臺北市政府捷運工日
# REQUIRED FOR UTILITY ARCHITECTURAL SYSTEMWIDE ECS
# MECHANICAL AND ELECTRICAL INSTALLATlON MAY
# AWS(美國焊接協會)--STRUCTURAL WELDING CODE-STEEL (AW$ D1.1-90)
# 結構鋼(臨時結構)厚度tSl6mm
# fy2 2500 kgf/cm2
# NOT BE SHOWN COMPLETELY ON STRUCTURAL DRAWINGS.
# THE CONTRACTOR SHALL REFER TO RELEVANT UTILITY,
# DEPARTMENT
# 0[
# RAPIDTRANSIT
# SYSTEMMS
# STRUCTURAL WELDING CODE-STEEL" (AWS D1.1-90)
# STRUCTURAL STEEL (FOR TEMPORARY STRUCTURES): ts16 mm
# ARCHITECTURAL SYSTEMWIDE
# ECS,
# MECHANICAL
# AND ELECTRICAL DRAWINGS (PRODUCED BY OTHERS) FOR THE
# TAIPEl
# CITY
# GOWERNMENT
# LOCATIONS AND DETAILS OF THESE ITEMS
# AND CONFIRM THEM WITH THE ENGINEER PRIOR To CONSTRUCTION
# REPUBLIC
# 0F
# GHINA
# (g)AWS(美國焊接協會)--STRUCTURAL WELDING CODE-REINFORCING STEEL (AWS D1.4-79)
# 16 mm<厚度t<40 mm
# fy2 2400 kgf/cm2
# STRUCTURAL WELDING CODE- REINFORCING STEEL'
# (AW/$ D1.4-79)
# 16 mmtts40 mm
# 混凝土澆置前
# 土建廠商應協調界面工程廠商或工程司
# 確認所有鋼筋
# 預埋螺栓
# 預埋管件`預留孔及開孔之確實
# (h)AlSC(美國鋼構{
# "MANUAL OF STEEL CONSTRUCTION"第九版1989
# 或ASTM A572 50級規定
# fy2 3500 kgf/cm2
# 位置
# 耋北市政府捷運工程局
# "MANUAL OF
# STEEL CONSTRUCTION" NINTH EDITlON 1989,
# AMERICAN INSTITUTE OF STEEL
# CONSTRUCTION INC
# OR CONFORM TO ASTM A572 GRADE 50
# 土建廠商應確認所有埋件埋設位置無誤
# 並於混凝土澆置前
# 將該項勘查紀錄乙份送工程司核可
# 午
# 月
#
# (i) 中華民國內政部頒佈之
# 建築物耐震設計規範及解說
# (100年版)
# 所有螺栓應為符合ASTM A325或CNS 11328或同等品規定之高拉力摩擦型螺栓
# 土建廠商施作電扶梯中間支撐及上
# 下機坑時
# 其位置及尺寸
# 應配合電扶梯標作調整
# 工 程圖 核 備 章
# 8
# ALL BOLTS SHALL BE HIGH-STRENGTH FRICTION GRIP BOLTS CONFORMING TO ASTM A325,
# (|/$ 11328 0R
# THE CIVIL CONTRACTOR SHALL ADJUST THE LOCATION OF ESCALATOR INTERMEDIATE SUPPORT
# 胄
# 地下車站
# 出入口
# 通風井
# 箱涵
# 隧道襯砌及明挖覆蓋隧道結構之頂版
# 底版`複合牆結構~需與頂
# 底版一起
# EQUlVALENT
# AND DIMENSION OF UPPER & LOWER PITS WITH THE ESCALATOR CONTRACTOR
# 細 部 設 計 廠 商
# DETAILDESIGNCON TRACTOR
# 澆置之局部外牆
# 厚度大於1.5M之版`牆結構及外牆(外側無連續壁時)
# 應使用CNS 61 TYPEI型卜特蘭水泥
# 或
# 機械螺栓及混凝土預鑄環片接合螺栓應符合A$TM A307
# 除非設計圖上另有註明者外
# 連續壁或其他開挖擋土設施於本工程施工完成後
# 其距完工地面以下至少2m或經工程
#
# CNS15286,IS(MS-MH)高爐爐渣熟料佔重量45土5%之高爐水泥
# 其餘結構包括外牆(外側有連續壁時)
# 中間牆
# MECHANICAL BOLTS AND BOLTS FOR PRECAST CONCRETE SEGMENTS SHALL CONFORM To ASTM A307
# 中興二趕願問服份有限公司
# 司核可位置鑿除
# 中間版
# 連續壁及隔間牆則使用CNS61 TYPE|型卜特蘭水泥
# 所有焊接鋼材焊材應為ETOXX並符合AWS D1.1規定
# DIAPHRAGM WALLS OR OTHER EXCAVATION SUPPORTS SHALL BE REMOVED TO AT LEAST TWO METERS BELOW
# Sinotech Engineering Consultants
# Lta
# 本標地下車站結構
# GO9` LG10)僅有外牆
# 穿堂層版
# 中間牆及頂版使用自充填混凝土:
# ALL WELDS OF STEEL SHALL BE E7OXX AND CONFORM TO AWS D1.1
# FINAL GROUND LEVEL OR APPROVE LOCATION BY THE ENGINEER AFTER COMPLETlON OF THE WORKS UNLESS
# PORTLAND CEMENT CONFORMING TO CNS61 TYPE
# OR CNS3654 IS(MS-MH) PORTLAND BLAST-FURNACE SLAG
# OTHERWISE SHOWN ON THE DRAWINGS
# 日期
# 日期
# 3
# CEMENT CONTAINING 45i5% SLAGIN WEIGHT SHALL BE USED FOR PARTS OF UNDERGROUND STRUCTURES OF
# 除工程司核可外承受撓曲應力或軸拉應力構件之焊接 禁用工地焊接
# CAD
# Date
# 核
# Date
# STATION BOX ENTRANCE VENT SHAFT BOX CULVERT TUNNEL LINING AND CUT & COVER TUNNEL INCLUDING
# UNLESS OTHERWISE APPROVED BY THE ENGINEER, THE FIELD WELDING FOR THE FLEXURAL OR TENSION MEMBERS
# 除工程司核可外
# 施工縫間距不得超過15m
# 另除了圖面註明者外 所有施工縫位置須經工程司核可;施工縫剪力樺
# 8
# Re(he(+e0
# ROOF SLAB
# BASE SLAB
# COMPOSITE WALL PARTS OF THE EXTERNAL WALL THAT NEEDS TO BE POURED
# PROHIBITED
# 方向須依施工順序決定
# 設
# 技
# TOGETHER WITH THE ROOF SLAB AND BASE SLAB THE SLAB OR WLL STRUCTURES WITH THICKNESS OVER 1.5M
# Designed
# Professlona
# 啡
# CONSTRUCTION JOINTS SHALL BE PROVIDED AT SPACING NOT EXCEEDING 15 m UNLESS OTHERWISE APPROVED
# AND EXTERNAL WALL( NO DIAPHRAGM WALL). FOR OTHER PARTS OF STATION BOX AND CUT& COVER TUNNEL
# lo.樓板設計活載重如下列:
# BY THE ENGINEER
# AND THE LOCATlON OF ALL CONSTRUCTION JOINTS,
# EXCEPT THOSE SHOWN ON THE
# INCLUDE EXTERNAL WALL( CLOSE TO DIAPHRAGM WALL)
# INNER WALL INNER SLAB
# DIAPHRAGM WALL AND
# LIVE LOADS FOR FLOOR DESIGN ARE AS FOLLOWS:
# Checkeo
# Projec Manager
# PARTITION WALL
# pORTLAND CEMENT CNS61 TYPE
# OF PORTLAND CONCRETE SHALL BE USED.
# CONTRACT DRAWINGS, SHALL BE APPROVED BY THE ENGINEER. THE ORIENTATlON OF ALL CONSTRUCTION JOINT
# FOR (LGO9 AND LG10) UNDERGROUND STATION ONLY EXTERNAL WALL CONCOURSE SLAB INNER WALL AND ROOF
# KEYS SHALL BE DETERMINED BY SEQUENCE OF CONSTRUCTION
# 臺北都會區捷運系統
# SLAB SHALL USE PORTLAND CEMENT OF SELF-COMPACTING CONCRETE.
# 車站
# 公眾區域
# 設備區域(非公眾區域)
#
# STATlON
# PUBLIC AREA
# PLANT AREA (NON-PUBLIC AREA)
# 地下構造物必須依圖示方式使其具適當的防水性
# 防水設施須依施
# 技術規範規定施作
# THIPEIETROP0LT|
# LRE
# 般混凝土粒料應符合CNS 1240規定且應為最大尺寸不大於25 mm者
# UNDERGROUND STRUCTURES SHALL BE ADEQUATELY WATERPROOFED AS SHOWN ON DRAWINGS
# RAPIDTRANSITSYSTEMS
# AGGREGATE FOR NORMAL WEIGHT CONCRETE SHALL CONFORM To CNS 1240 AND WITH AGGREGATE SIZE NOT
# (a)
# 穿堂層
# O.5 ton/m2
# l.0 ton/m2
# WATERPROOFING SHALL BE CARRIED OUT AS PER PROJECT SPECIFICATIONS
# GREATER THAN 25 mm
# CONCOURSE
# 萬大-中和-樹林線(第二期工程)
# 土建廠商須協調係統廠商確認 CSD/SEM之最終需求(設備混凝土基座`開孔
# 預埋套管
# 係統標之預埋導線管.
# 等)
# //3003
# 7h0n0`e
# Sh1-
# C
# Project Phase
# %
# 焊接鋼線網應符合ASTM A185或CNS 6919規定
# (b)月台層
# O.5 ton/m
# l.0 ton/m2
# 納入土建施工圖說配合施作,土建廠商須於施作前 洽請供電廠商提出設備基座需求
# 以確認基座尺寸`位置`承載
# STEEL WELDED WIRE FABRIC SHALL CONFORM TO ASTM A185 OR CNS 6919
# PLATFORM LEVEL
# 力及高度符合係統需求
# 結構
# 般說明
#
# 混凝土板厚若超過1.
# m應視為巨積混凝土
# 其規定細貝
# 閱施工技術規範
# 軌道層
# l.0 ton/m2
# 10.有
# 關建築所需之開孔(門
# 窗)尺寸及高程
# 廠商應依照AR圖施作
# 第1張共2張
# CONCRETE SLABS THICKER THAN l.5m SHALL BE TREATED AS MASS CONCRETE, SEE DETAIL DESCRIPTION OF
# TRACK LEVEL
# STRUCTURAGENERAL NOTES
# CONSTRUCTIOI SPECIFICATION
# ALL ARCHITECTURAL OPENINGS (FOR INSTALLATION OF DOORS AND WINDOWS) SHALL BE PROVIDED AS THE AR
# DRAWINGS SHOWN
# SHEET
# 0F2
# 8
# 號
# 0881/$E 001
# DrgNo
# FOR
# 318
# 協會)-
# Eng

# %%
import re
def get_the_num(string):
  x = []
  for j,k in enumerate(string):
    if k == ' ' or k == '=' :
      x.append(j)
  if len(x) < 2:
    x.append(x[0])
    for c,w in enumerate(string):
      if w == '2':
        x[0] = c
        break
  return string[x[0]+1 : x[1]]

def check_is_right(string):
    pattern = r'(\d+)\s*kgf/cm2'
    match = re.search(pattern, string)
    if match:
        return int(match.group(1))
    else:
        return None
        
def extrct_data(bounds):
        s_big_word = '直徑大於'
        s_small_word = '直徑小於'
        result_dic = {'Concrete Strength':{'strength1':'0', 'strength2':'0'},
                          'Rebar Strength':{'strength1':'0', 'strength2':'0'}}

        lengths_of_bounds = len(bounds)
        
        for i in range(lengths_of_bounds):
            # check rebar strength 1
            if bounds[i][1].find(s_big_word) > -1:
                s_big_start = i
                while True:
                    if (bounds[s_big_start][1].upper()).find('KGF') > -1:
                        result_dic["Rebar Strength"]['strength1'] = get_the_num(bounds[s_big_start][1])
                        print(f'rebar strength 1: {result_dic["Rebar Strength"]["strength1"]}')
                        break  
                    s_big_start += 1
            

            # check rebar strength 2
            if bounds[i][1].find(s_small_word) > -1:
                s_small_start = i
                while True:
                    if (bounds[s_small_start][1].upper()).find('KGF') > -1:
                        result_dic["Rebar Strength"]['strength2'] = get_the_num(bounds[s_small_start][1])
                        print(f'rebar strength 2: {result_dic["Rebar Strength"]["strength2"]}')
                        break
                    s_small_start += 1
            

            # check wall strength1
            if bounds[i][1].find('最小抗壓強度') > -1:
                search_index = i
                while True:
                    if bounds[search_index][1].find('連續壁') > -1:
                        
                        check = check_is_right(bounds[search_index+1][1])
                        if check:
                            result_dic["Concrete Strength"]['strength1'] = check
                            print(f'wall strength1: {result_dic["Concrete Strength"]["strength1"]}')
                    if bounds[search_index][1].find('WALLS') > -1:
                        check = check_is_right(bounds[search_index+1][1])
                        if check:
                            result_dic["Concrete Strength"]['strength2'] = check
                            print(f'wall strength2: {result_dic["Concrete Strength"]["strength2"]}')
                        break
                    search_index += 1

        return result_dic

result_dic = extrct_data(bounds)
print(result_dic)
# Out:
# wall strength1: 245
# wall strength2: 350
# rebar strength 1: 4200
# rebar strength 2: 2800
# {'Concrete Strength': {'strength1': 245, 'strength2': 350}, 'Rebar Strength': {'strength1': '4200', 'strength2': '2800'}}

# %%
def extract_number(text):
    pattern = r'(\d+)\s*kgf/cm2'
    match = re.search(pattern, text)
    if match:
        return int(match.group(1))
    else:
        return None

# 使用範例
text = "f'c2 245 kgf/cm^2"
result = extract_number(text)
print(result)  # 輸出: 245
# Out:
# 245
