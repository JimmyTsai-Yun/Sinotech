# %%
import cv2
import numpy as np
import sys
import os 
from pdf2image import convert_from_path
import easyocr
import csv
import matplotlib.pyplot as plt

# %%
image = convert_from_path('./-Layout1(1).pdf', dpi =300)

# %%
img = np.asarray(image[0])

img_gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
reader = easyocr.Reader(['ch_tra','en'])

bounds = reader.readtext(img_gray, detail=1)
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
for index in bounds:
  print(index[1])
# Out:
# 結 構一般說 明
# STRUCTURAL GE IERAL WOTES
# 除非另有說明
# UllLESS OTHER IISE HOTED
# 般
# 所有結構混凝土應為常重混凝土且其28天之最小抗壓強度應如下列:
# .施工說明
# GEl IERAL
# ALL STRUCTURAL COHCRETE SHALL BE OF HORMAL WEIGHT COHCRETE WITH MlHllUM COMPRESSIE STREIIGTH
# COlSTRUCTIOI/ HlOTES
# AT 28 DA/S fc AS F0[_01/$:
# 廠商於施工前必須先行確認設計圖上之所有尺寸及可能影響施工之任何狀況並告知工程司設計圖上有疑義處
# 鋼筋保護層厚度應至少如下:
# THE COllTRACTOR SHALL IMMMEDIATEL{ UPOIl RECEIPT THEREOF
# CHECK COllTRACT DRAiilHlGS
# FURIISHED FOR
# 連續壁
# f'c2 245 kgf/cm2
# COllCRETE PROTECTIOII FOR REIHFORCEI EIIT SHALL BE HOT LESS THAII THAT FOLLO iS:
# THE DIMEIISlOlS AllD COliDITlOliS AFFECTIIIG HIS ORKS AllD SHALL PROMPTL/ MOTIF/ THE ElGIlIEER OF
# DlAPHRAGM WALLS
# 350 kgf/cm2
# OlilSSl0iIS OR DISCREPAIICIES
# 合牆適用
# 外露面直接接觸水`土壤`混凝土舖面或防水膜者
# T5 mm
# FOR COMPOSITE IALL
# COllCRETE CAST AGAIlST AllD PERMAlIElITL| EXPOSED TO WATER SOlL
# BLllID|||6
# 2.
# 為使高程值為正值
# 本設計圖所有高程標示均以中華民國台灣省基隆潮汐測站之平均海平面下100公尺處為基準點
# COllCRETE OR WATERPROOFIIIG MEMBRAlIE
# ALL ELE ATlOlS SHOlll Oll THESE COllTRACT DRAWIHGS ARE RELATED TO THE DATUM 1OO m BELOlI THE
# MEAI4 SEA LE EL AT TIDAL STATIOII KEELUllG
# TAlllAll REPUBLIC OF CHIllA
# T0 AlOID HEGATI E FIGURES FOR
# 無筋混凝土(保護
# 舖底
# f'c2 140 kgf/cm2
# 外露面暴露於室外之
# ELE ATlOllS
# PLAll4  PROTECTIE BLHiDIHG COlICRETE
# COllCRETE EXPOSED TO  WEATHER
# 結構體之高程控制係以低軌之鋼軌頂面為基準
# 水平控制則以軌道線形為基準
# -般結構(含軌床二次混凝土)
# 280 kgf/cm2
# fil王筋
# 50 mm
# THE ERTICAL COlTROL OF THE STRUCTURE IS BASED Oll THE ELE ATlOI OF THE TOP OF LOWIER RAIL
# GElIERAL STRUCTURAL WORKS IIHCLUDE 2nd STAGE COHCRETE OF TRACK BED)
# pRIMARY RElHFORCEM IEIIT
# HORIZOllTAL COllTROL
# BASED Oll THE TRACK ALIGMMElIT
# 預鑄混凝土隧道環片
# f'c2 450 kgf/cm2
# fii)箍筋~繫筋`螺旋箍筋
# 40 mm
# 本設計圖所有尺寸標示均以公厘為單位;所有高程標示均以公尺為單位
# PRECAST COlCRETE TUlllEL LllllG
# STIRRUPS
# TIES
# L|D
# SPIRALS
# ALL Dll E SlOllS ARE IIl MILLIM ETERS AlID ALL ELE ATlOIS ARE Ill METERS
# 隧道仰拱(二次混凝土)
# f'c2 210 kgf/cm2
# fiii)月台板及牆主筋
# 25 mm
# 本設計圖標示之樓板高程係指結構面樓板高程(SFL).
# TUllllEL IHVERT COlCRETE  Znd STAGE COlCRETE
# PRIM AR|
# REIHFORCEMENT FOR PLATFORM SLAB AND ITS SUPPORTIHG WALL
# FLOOR LEVELS SHOiill Ill THESE COlTRACT DRAiilHGS ARE STRUCTURAL FLOOR SLAB LE ELS ISFL
# 場鑄隧道襯砌
# f'c2 280 kgficm2
# 外露面暴露於鹽水中或有受鹽水噴灑之虞者
# L00 mm
# 本設計圖標示之高程及尺寸係指結構完工需求面
# CAST-I|1-PLACE CO| CRETE Lllll|16
# COllCRETE EXPOSED TO SALT WATER OR SALT WATER SPRAf
# LE ELS AlID DIlEHISIOHS SHOlII ARE REFERRED TO THE REQUIRED COMPLETED STRUCTURAL SURFACES
# 場鑄樁
# f'c2 280 kgficm2
# 混凝土蓋板
# 40 mm
# 廠商必須考慮可能影響結構尺寸之施工誤差及連續壁或其他開挖擋土設施撓度 x保持永久結構之設計尺寸需求
# CAST-||l-PLACE PILE
# COllCRETE CO ER
# THE COllTRACTOR SHALL COHSIDER COHSTRUCTIOI TOLERAHICE AllD DEFLECTIOI OF DIAPHRAGM WALL OR THE
# OTHER EYCA ATIOI SUPPORTS WHICH MlAf AFFECTIIIG STRUCTURE SIZE TO KEEP THE DESIGII DllElISlOllS
# 鋼筋:
# 內面僅暴露於空氣中之
# REIHFORCEM IEIIT:
# COllCRETE EAPOSED TO AIR OlILi
# 設計準則及施工規範
# DESIGII CRITERIA AllD SPECIFICATlOllS
# ia
# 直徑大於或等於13mm之鋼筋應符合[|/$ 560, SD420//之鋼材
# fy2 4200 kgf/cm2
# fi) 主筋
# 40 mm
# REIHFORCEMEIT OF 13 mm OR LARGER II DIAMETER SHALL CollFORI  To CIIS 560,
# PRIMAR/ RElHFORCEM IEIIT
# 所有材料及工法均應符合本標施工技術規範及特定條款規定
# 50420 //.
# ALL MATERIALS AHID WORKMAlISHIP SHAL_ COMPL/ WITH PROJECT SPECIFICATlOllS
# fii)
# 箍筋`繫筋`螺旋箍筋
# 30 mm
# fb)
# 直徑小於或等於1Omm之鋼筋應符合[|$ 560 SD280'//鋼材;或符合[|/$ 560,$0280
# fy2 2800 kgf/cm2
# STIRRUPS TIES AlD SPIRALS
# 2.
# 本標結構設計係依據下列規範:
# 之鋼材之規定
# THE STRUCTURAL DESIGI IS BASED Oll THE FOLLOiillG DOCul lElITS:
# fiii)月台板及牆主筋
# 25 mm
# REIHFORCEM IEIIT OF lo mm OR SMALLER III DlAl ETER SHAL_ CollFoRi  To CIIS560
# 5D280 // 0R [|1$ 560 50280
# PRIMARY RElHFORCEM EHT FOR PLATFORM SLAB AHD ITS SUPPORTIIG WIALL
# fa)
# 台北捷運係統-土木工程設計準則中文版第01版
# TRTS "CIIL ElGIIIEERIHG DESIGII CRITERIOII" lst ED. Ill CHIIIESE
# (C
# 除符合[|/$ 560,$0420//,5D280//之鋼筋外
# 其餘所有鋼筋若需焊接均應提送符合AWS Dl.4焊接程序規定的材料
# 預鑄混凝土隧道環片
# PRECAST COlCRETE TUllllEL LllllllG
# fb)ACI(美國混凝土協會- BUlLDllG CODE REOUlREMElTS
# STRUCTURA_ COllCRETE AC|318-05|
# 性質報告
# SD420 //焊接鋼筋之焊材應為E9OXX SD280//焊接鋼筋之焊材應為ETOxX 並均應符合AWS D1.4規定
# "BUlLDI|I6 CODE REQUIREM ElITS FOR STRUCTURAL COHCRETE'
# (/C|/ 318-05)
# ALL RElHFORCEM IEIIT TO BE WELDED ARE REQUIRED TO HAVE
# REPORT OF MATERIAL PROPERTIES HECESSAR|
# 它側
# 40 mm
# To COllFORM To WELDIHIG PROCEDURES SPECIFIED II AlS DL.4 EYCEPT FOR CllS 560
# 50420//,50280//), A__
# OTHER FACE
# fc)IlTERMIATOlAL BulLDiHG CODE
# 2O06版(IBC
# WELDS OF RElHFORCEI IElIT SHALL BE EgOxx FOR SD420ii
# E7O// FOR SD280/ AIID COlFOR|/ T0 ///5
# "ITERIIATlOllAL BUlLDlllG CODE'
# 2006 EDIT|0|4 (IBC
# D1.4
# 內側
# 30 mm
# IHTERIIAL FACE
# 次序
# 日期
# 內
# 容
# 口口(
# DORTS
# (d)
# 中華民國內政部頒布之"建築技術規則"
# 結構鋼(永久結構)應符合/$T|/ A36(或[|1$ 2473/C|1$ 2947)規定
# fy2 2500 kgficm2
# Ho
# Date
# Descriotion
# MlllISTR OF IITERIOR
# R.0.(
# BUlLDi|l6 COl ISTRUCTl0|1 REGUL/T|0115'
# STRUCTURAL STEEL FOR PERMAHIEIIT STRUCTURES
# SHALL COllFORI  To ASTI A36 OR
# 連續壁(雙面
# T5 mm
# 准
# 改 Revisions
# Approweo
# C|1$ 2473/0|1$ 2947)
# DIAPHRAGMA IALLS IBOTH FACES
# fe)美國州
# |際公路及運輸官員協會制訂之"STAHDARD SPECIFICATOI FOR HIGHWA/ BRIDGES"並併入美國
# 參考圖號
# 電腦圖號
# 088&s1$6:0
# 或[||$ 13812 5|14908
# (||$13812 5|1490(
# (|1$ 13812 5|1490C|/之規定
# fy2 3o00 kgficm2
# 因應公共管線`建築
# 係統化設施`環控係統及機電設備等需求之預埋管件
# 如預埋管`預埋件`套筒`導管`基座
# Pe-
# M0
# CL口
# 0
# 加州運輸部結構設計課制訂之修定版
# OR COlFORI To
# (|1$ 13812 5|14903 0|1$ 13812 5|1490[ [|1$ 13812 5|1490C|/1
# 比例
# 單位
# "STAIIDARD SPECIFICATlOIS FOR HIGHiAY BRIDGES
# ADOPTED BY THE AMMERICAlI ASSOCIATlOIl OF STATE
# 及某些凹槽或開孔 也許並未完整地標示於結構圖上 廠商於施工前必須參考公共管線
# 建築
# 係統化設施`環控
# Scale
# Unit
# HlGHiAl AHD TRAHSPORTATlOl OFFICIALS IHC.
# MITH RE ISIOHS Bl STATE OF CALIFORIIA DEPARTMEIT OF
# 或ASTM A5T2 50級規定
# fy2 3500 kgf/cm2
# 係統及機電設備等相關圖說(由其他單位設計)先行和工程司確認其位置及詳圖
# TRAiSPORTATIOII OFFICE OF STRUCTURE DESIGIl (C-AASHTO
# OR COllFORI  To ASTI A5T2 GRADE 50
# ElBEDDED ITEMS SUCH AS PIPES
# IMSERTS SLEE ES
# COllDU|T5
# PLIHITHS AIID SOl lE RECESSES OR OPElllllGS
# 中華民國臺北市政府捷運工u
# REQUIRED FOR UTILIT/ ARCHITECTURAL SYSTEMWIDE ECS
# MECHAIlICAL AlID ELECTRICAL IHSTALLATlOll MAl
# AWS(美國焊接協會--STRUCTURAL WELDIII6 CODE-$TEE_ A//$ 01.1-90
# 結構鋼(臨時結構)厚度tSlomm
# fy2 2500 kgf/cm2
# MOT BE SHOiiIl COMPLETEL/ Oll STRUCTURAL DRAiilll6S.
# THE COllTRACTOR SHALL REFER TO RELE/AllT UTILITi
# DEPARTMEHIT
# OF
# RAPID
# TRAHSIT
# SYSTEI/S
# "STRUCTURAL WELD|||6 CoDE-STEEL"  A/$ D1.1-90|
# STRUCTURAL STEEL  FOR TEMPORARY STRUCTURES|: tsl6 mm
# ARCHITECTURAL SYSTEMIIDE
# ECS
# MECHAlIICAL
# AHID ELECTRICAL DRAfllGS PRODUCED B/ OTHERS FOR THE
# TAIPE|
# CIT/
# GO ERIII EIIT
# LOCATlOlI5 AIID DETAILS OF THESE ITEMS
# AlID COlIFIRMI THEM WITH THE EllGIIIEER PRIOR To COlSTRUCTIOII
# REPUBLIC
# OF
# CHlllA
# ig)AWS美國焊接協會--STRUCTURAL WELDIIG CODE- REIlFORCIIIG STEEL  A/S D1.4-79|
# 16 mm<厚度t蘭40 mm
# fy2 2400 kgficm2
# "STRUCTURAL WELDIHG CODE- REIHIFORCIIIG STEEL'
# (4//$ 01.4-79|
# 16 mmtt
# 40 mm
# 混凝土澆置前.土建廠商應協調界面工程廠商或工程司
# 確認所有鋼筋
# 預埋螺栓
# 預埋管件
# 預留孔及開孔之確實
# Ih)
# AISC(美國鋼構協會-
# MAHUAL OF STEEL COMSTRUCTIOI"第九版1989
# 或ASTM A5T2 50級規定
# fy2 3500 kgf/cm2
# 位置
# 耋北市政府捷運工程局
# 罩
# "MAHUAL OF STEEL CollSTRUCT|Ol/" /lll/TH EDITIO|/ 1989
# AMERICAl4 IHSTITUTE OF STEEL
# OR COllFORI  To ASTI A572 GRADE 50
# COlSTRUCTIOl IllC
# 土建廠商應確認所有埋件埋設位置無誤
# 並於混凝土澆置前
# 將該項勘查紀錄乙份送工程司核可
# 午
# 月
# fi) 中華民國內政部頒佈之
# 建築物耐震設計規範及解說_(l00年版
# 所有螺栓應為符合A$T|/ A325或C|S 11328或同等品規定之高拉力摩擦型螺栓
# 土建廠商施作電扶梯中間支撐及_
# 下機坑時
# 其位置及尺寸
# 應配合電扶梯標作調整
# 工 程圖 核 備 章
# ALL BOLTS SHALL BE HIGH-STREHGTH FRICTION GRIP BOLTS COMFORMII6 TO ASTM A325
# [||$11328 0R
# THE ClVIL COllTRACTOR SHALL ADJUST
# THE LOCATlOIl OF ESCALATOR IHTERM EDIATE SUPPORT
# 地下車站
# 出入口`通風井`箱涵
# 隧道襯砌及明挖覆蓋隧道結構之頂版
# 底版~複合牆結構
# 需與頂
# 底版一起
# EQUl ALEIT
# AlID DllEHSlOll OF UPPER & LOWER PITS WITH THE ESCALATOR COllTRACTOR
# 細 部 設 計 廠 商
# DETAIL DESIGII COllTRACTOR
#
# 澆置之局部外牆
# 厚度六於1.5M之版`牆結構及外牆(外側無連續壁時)
# 應使用CMS6lT/PEl型~特蘭水泥
# 或
# 機械螺栓及混凝土預鑄環片接合螺栓應符合/$T|/1 A307
# 除非設計圖上另有註明者外 連續壁或其他開挖擋土設施於本工程施工完成後
# 其距完工地面)下至少2m或經工程
# C|$15286,|$|MS-|/H)高爐爐渣熟料佔重量45+5%之高爐水泥
# 其餘結構包括外牆(外側有連續壁時)
# 中間牆
# MECHAlICAL BOLTS AliD BOLTS FOR PRECAST COlCRETE SEGMEIITS SHAL_ COllFoRi  To ASTI A307
# 中興工捏頤問服份有限公司
# 司核可位置鑿除
# 中間版
# 連續壁及隔間牆則使用CHS6LT/PE|型卜特蘭水泥
# 所有焊接鋼材焊材應為ETOYX並符合AWS D1.1規定
# DIAPHRAGM WALLS OR OTHER EYCA ATlOI SUPPORTS SHALL BE REMO ED TO AT LEAST TWlO METERS BELOll
# Sinotech Engineering Consultants
# Ltd.
# 本標地下車站結構(LG09` LG10)僅有外牆`穿堂層版`中間牆及頂版使用自充填混凝土
# ALL WELDS OF STEEL SHALL BE ETOYr AllD COllFoRI  To AiiS D1.1
# FlllAL GROUlID LEVEL OR APPROIE LOCATlOIl Bi THE ElGIIIEER AFTER COMPLETlOI OF THE WORKS
# UllLESS
# PORTLAlID CEMElT COlFORi liiG To CllS6l T/PE
# OR CIlS3654 IS|S-|| PORTL/IID BLAST-F0R/|/CE 5[/6
# OTHER IISE SHOlill Oll THE DRAiilllGS
# 日期
# CEMElT COllTAllllll6 45t5% SLAGIl/ EIGHT SHAL_ BE USED FOR PARTS OF UHDERGROUlID STRUCTURES OF
# 除工程司核可外承受撓曲應力或軸拉應力構件之焊接 禁用工地焊接
# CAD
# Date
# 核
# Date
# 舞
# STATIOlI BOx ElITRAIICE, EHT SHAFT BOY CUL ERT TUllllEL LilllG AllD CUT& Co ER TUllllEL IHCLUDIIG
# UHLESS OTHER IISE APPRO ED BY THE EHGIHIEER, THE FIELD WELDIIG FOR THE FLEYURAL OR TEHSIOII MEMBERS
# 除工程司核可外 施工縫間距不得超過15m 另除了圖面註明者外 所有施工縫位置須經工程司核可;施工縫剪力樺
# Draln
# #ere(+eo
# ROOF SLAB BASE SLAB
# COMPOSITE WHLL PARTS OF THE EYTERHAL WALL THAT HEEDS TO BE POURED
# PROHIBITED
# 方向須依施工順序決定
# 設
# 計
# 技
# 師
#
# TOGETHER WITH THE ROOF SLAB AliD BASE SLAB THE SLAB OR HLL STRUCTURES IlTH THICKIESS OlER 1.5M
# COlSTRUCTlOl1 JOIlITS SHAL_ BE PROIDED AT SPACIIG IOT EXCEEDIII6
# UlLESS OTHER IISE APPRO ED
# Designed
# Professional
# AlID ETERIIAL WALL HO DIAPHRAGM WALL
# FOR OTHER PARTS OF STATIOII BON AllD CUT& COER TUlllIEL
# 10.
# .樓板設計活載重如下列:
# B{ THE ElGII IEER
# AHID THE LOCATlOll OF HLL COllSTRUCTIOll JolllTS
# EYCEPT THOSE SHOiill Oll THE
# IHCLUDE EYTERIAL WALL CLOSE TO DlAPHRAGM WALL
# IMllER WALL IllER SLAB
# DIAPHRAGM WALL AlID
# LIE LOADS FOR FLOOR DESIGII ARE AS FOLLO IS:
# Checkeo
# Project Manager
# PARTITIOII IAL_
# PORTLAIID CEMElIT ClS6l TYPE
# OF PORTLAHID COllCRETE SHALL BE USED.
# COllTRACT DRAliIHGS SHALL BE APPROVED BY THE EHGIIIEER. THE ORIEHTATlOIl OF ALL COlSTRUCTIOll JolllT
# FOR LGO9 AlID LG10| UlDERGROUlID STATIOII OllL/ EYTERIAL WALL COHCOURSE SLAB IHHER WALL AlID ROOF
# KE/S SHALL BE DETERMIIIIED Bi SEQUEIICE OF COlSTRUCTIOlI
# 臺北都會區捷運系統
# SLAB SHAL_ USE PORTLAIID CEM EIIT OF SELF- COMIPACTIIIG COlCRETE.
# 車站
# 公眾區域
# 設備區域(非公眾區域
#
# STATlOl4
# PUBLIC AREA
# PLAllT AREA MOll-PUBLIC AREA
# 地下構造物必須依圖示方式使其具適當的防水性
# 防水設施須依施工技術規範規定施作
# TAIPEl METROPOLTAIl ARE/
# 般混凝土粒料應符合CHS 1240規定且應為最大尺寸不六於25 mm者
# UllDERGROUlID STRUCTURES SHALL BE ADEQUA
# IATERPROOFED AS SHOiill Oll DRAiilll65
# RAPID TRAlISIT SYSTElIS
# AGGREGATE FOR MORMAL WEIGHT COlCRETE SHALL COlFORI To CllS1240 AiID WITH AGGREGATE SIZE IOT
# ta)
# 穿堂層
# O.5 ton m
# l.0 tonim2
# MATERPROOFIHG SHALL BE CARRIED OUT AS PER PROJECT SPECIFICATlOllS
# GREATER THAll 25 mm
# COllCOURSE
# 萬大_中和
# 樹林線(第二期工程
# 土建廠商須協調係統廠商確認CSD|SEM/之最終需求{設備混凝土基座
# 開孔
# 預埋套管
# 係統標之預埋導線管.
# 等
# Ianda - Zhonghe
# Shulin
# i
# Project Phase
# 喜
# 焊接鋼線網應符合ASTM Al85或C|S 6919規定
# %b)月台層
# O.5 ton m
# l.0 tonm2
# 納入土建施工圖說配合施作 土建廠商須於施作前 洽請供電廠商提出設備基座需求
# 以確認基座尺寸`位置`承載
# STEEL WELDED  WIRE FABRIC SHAL_ COllFoRi  To ASTI/ A185 OR CIlS 6919
# PLATFORIA LE EL
# 力及高度符合係統需求
# 結構一般說明
#
# 混凝土板厚若超過1.5 m應視為巨積混凝土'其規定細則參閱施工技術規範
# 軌道層
# l.0 tonm2
# 10.有關建築所需之開孔(門
# 窗)尺寸及高程
# 廠商應依照 AR圖施作
# 第1張共2張
# COllCRETE SLABS THICKER THAll l.5m SHALL BE TREATED AS MASS COlCRETE SEE DETAIL DESCRIPTIOIl OF
# TRACK LE EL
# STRUCTURAL GElERAL MOTES
# COlISTRUCTIOII SPECIFICATlOII
# ALL ARCHITECTURAL OPElllllGS FOR IHSTALLATIOI OF DOORS AllD WillDOlS SHALL BE PROVIDED AS THE AR
# DRA ill65 SHOiIII
# SHEET
# OF2
#
# Drg
# Ho.
# 0881/S[ 001
# fc二
# fc2
# FOR
# Eng:
# 15 m
# TELY

# %%
import re
def get_the_num(string):
  x = []
  for j,k in enumerate(string):
    if k == ' ' or k == '=' :
      x.append(j)
  if len(x) < 2:
    x.append(x[0])
    for c,w in enumerate(string):
      if w == '2':
        x[0] = c
        break
  return string[x[0]+1 : x[1]]

def check_is_right(string):
    pattern = r'(\d+)\s*kgf/cm2'
    match = re.search(pattern, string)
    if match:
        return int(match.group(1))
    else:
        return None
        
def extrct_data(bounds):
        s_big_word = '直徑大於'
        s_small_word = '直徑小於'
        result_dic = {'Concrete Strength':{'strength1':'0', 'strength2':'0'},
                          'Rebar Strength':{'strength1':'0', 'strength2':'0'}}

        lengths_of_bounds = len(bounds)
        
        for i in range(lengths_of_bounds):
            # check rebar strength 1
            if bounds[i][1].find(s_big_word) > -1:
                s_big_start = i
                while True:
                    if (bounds[s_big_start][1].upper()).find('KGF') > -1:
                        result_dic["Rebar Strength"]['strength1'] = get_the_num(bounds[s_big_start][1])
                        print(f'rebar strength 1: {result_dic["Rebar Strength"]["strength1"]}')
                        break  
                    s_big_start += 1
            

            # check rebar strength 2
            if bounds[i][1].find(s_small_word) > -1:
                s_small_start = i
                while True:
                    if (bounds[s_small_start][1].upper()).find('KGF') > -1:
                        result_dic["Rebar Strength"]['strength2'] = get_the_num(bounds[s_small_start][1])
                        print(f'rebar strength 2: {result_dic["Rebar Strength"]["strength2"]}')
                        break
                    s_small_start += 1
            

            # check wall strength1
            if bounds[i][1].find('最小抗壓強度') > -1:
                search_index = i
                while True:
                    if bounds[search_index][1].find('連續壁') > -1:
                        
                        check = check_is_right(bounds[search_index+1][1])
                        if check:
                            result_dic["Concrete Strength"]['strength1'] = check
                            print(f'wall strength1: {result_dic["Concrete Strength"]["strength1"]}')
                    if bounds[search_index][1].find('WALLS') > -1:
                        check = check_is_right(bounds[search_index+1][1])
                        if check:
                            result_dic["Concrete Strength"]['strength2'] = check
                            print(f'wall strength2: {result_dic["Concrete Strength"]["strength2"]}')
                        break
                    search_index += 1

        return result_dic

result_dic = extrct_data(bounds)
print(result_dic)
# Out:
# wall strength1: 245
# DlAPHRAGM WALLS
# 350 kgf/cm2
# wall strength2: 350
# rebar strength 1: 4200
# rebar strength 2: 2800
# {'Concrete Strength': {'strength1': 245, 'strength2': 350}, 'Rebar Strength': {'strength1': '4200', 'strength2': '2800'}}

# %%
def extract_number(text):
    pattern = r'(\d+)\s*kgf/cm2'
    match = re.search(pattern, text)
    if match:
        return int(match.group(1))
    else:
        return None

# 使用範例
text = "f'c2 245 kgf/cm^2"
result = extract_number(text)
print(result)  # 輸出: 245
# Out:
# 245
